# %% [markdown]
# <a href="https://colab.research.google.com/github/wiz124/chem169-git/blob/main/Li_Harry_RID_007_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Exercise 2
with open('chem169-git/notes.txt', 'w') as f:
  f.write('Hello world')

# %% [markdown]
# Exercise 2
#
# Before staging, git status shows no changes to add. After commiting, git status states that the change was saved and updates whether or not the repo is different from the original remote repo. After staging, git status will show the changes that are ready for the next commit.

# %% [markdown]
# Exercise 4
# What happened was git pull updates the local repo to match the remote repo. The browswer edits appear directly in the file.

# %% [markdown]
# Exercise 5
# How do I switch branches?

# %%
#Exercise 5
'''
git switch <branch_name>

#to create and switch to a new branch
git checkout -b <new_branch_name>

'''
